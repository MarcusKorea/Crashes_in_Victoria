# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
print("Expect vehicle to vehicle collisions highest frequency accident type")
# Out:
# Expect vehicle to vehicle collisions highest frequency accident type

# %%
# Import cleaned weather data
crashes_path = 'cleaned_data/all_crashes.csv'
crashes = pd.read_csv(crashes_path)
crashes.head()
# Out:
#    Unnamed: 0  OBJECTID   ACCIDENT_NO          ABS_CODE ACCIDENT_STATUS  \
# 0           0         1  T20140013514  Driving accident      Unfinished
# 1           1         2  T20140013549  Driving accident        Finished
# 2           3         4  T20140013563  Driving accident        Finished
# 3           4         5  T20140013567  Driving accident        Finished
# 4           5         6  T20140013582  Driving accident        Finished
#
#   ACCIDENT_DATE ACCIDENT_TIME ALCOHOLTIME                  ACCIDENT_TYPE  \
# 0    2014/07/01      13:09:00          No         Collision with vehicle
# 1    2014/07/02      00:01:00         Yes         Collision with vehicle
# 2    2014/07/02      10:08:00          No         Collision with vehicle
# 3    2014/07/02      09:12:00          No         Collision with vehicle
# 4    2014/07/02      12:20:00          No  Collision with a fixed object
#
#   DAY_OF_WEEK  ... NO_OF_VEHICLES HEAVYVEHICLE PASSENGERVEHICLE MOTORCYCLE  \
# 0      Monday  ...            2.0          0.0              2.0        0.0
# 1   Wednesday  ...            2.0          0.0              2.0        0.0
# 2   Wednesday  ...            2.0          0.0              2.0        0.0
# 3   Wednesday  ...            2.0          1.0              1.0        0.0
# 4   Wednesday  ...            1.0          0.0              0.0        1.0
#
#   PUBLICVEHICLE DEG_URBAN_NAME DEG_URBAN_ALL  LGA_NAME_ALL  \
# 0           0.0          TOWNS         TOWNS      MITCHELL
# 1           0.0     MELB_URBAN    MELB_URBAN    WHITTLESEA
# 2           0.0     MELB_URBAN    MELB_URBAN       WYNDHAM
# 3           0.0     MELB_URBAN    MELB_URBAN       WYNDHAM
# 4           0.0     MELB_URBAN    MELB_URBAN  PORT PHILLIP
#
#                   REGION_NAME_ALL  STAT_DIV_NAME
# 0                 NORTHERN REGION        Country
# 1  METROPOLITAN NORTH WEST REGION          Metro
# 2  METROPOLITAN NORTH WEST REGION          Metro
# 3  METROPOLITAN NORTH WEST REGION          Metro
# 4  METROPOLITAN NORTH WEST REGION          Metro
#
# [5 rows x 53 columns]

# %%
crashes["LGA_NAME"].value_counts()
# Out:
# MELBOURNE                    3977
# CASEY                        3118
# GEELONG                      2957
# DANDENONG                    2492
# HUME                         2478
#                              ...
# (FRENCH ISLAND)                 2
# MOUNT BULLER ALPINE RESOR       2
# (MOUNT STIRLING)                2
# MOUNT HOTHAM ALPINE RESOR       2
# MOUNT STIRLING ALPINE RES       1
# Name: LGA_NAME, Length: 91, dtype: int64

# %%
sizes=crashes["LGA_NAME"].value_counts()
x=sizes[sizes>2000]
#lables = x["LGA_NAME"].unique()
#crashes.plot.bar(lables,x)
x.plot.bar(x)


plt.xlabel("Suburbs")
plt.ylabel("Number of Accidents")



plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
crashes["STAT_DIV_NAME"].value_counts()
# Out:
# Metro      52938
# Country    23461
# Name: STAT_DIV_NAME, dtype: int64

# %%
crashes[crashes["LGA_NAME"]=="CASEY"]["STAT_DIV_NAME"]
# Out:
# 6        Metro
# 36       Metro
# 55       Metro
# 68       Metro
# 87       Metro
#          ...
# 76298    Metro
# 76303    Metro
# 76313    Metro
# 76370    Metro
# 76376    Metro
# Name: STAT_DIV_NAME, Length: 3118, dtype: object

# %%
labels = ["Metro", "Country"]

# The values of each section of the pie chart
sizes = [52938, 23461]

# The colors of each section of the pie chart
colors = ["red", "orange"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0,)

# %%
plt.bar(labels,sizes)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 2 artists>

# %%
crashes["DEG_URBAN_ALL"].value_counts()
# Out:
# MELB_URBAN                                 46169
# RURAL_VICTORIA                             17281
# LARGE_PROVINCIAL_CITIES                     4261
# SMALL_CITIES                                3916
# TOWNS                                       2342
# SMALL_TOWNS                                  669
# MELBOURNE_CBD                                596
# MELB_URBAN,RURAL_VICTORIA                    397
# MELB_URBAN,MELBOURNE_CBD                     362
# RURAL_VICTORIA,SMALL_CITIES                  133
# RURAL_VICTORIA,TOWNS                         119
# LARGE_PROVINCIAL_CITIES,RURAL_VICTORIA        56
# RURAL_VICTORIA,SMALL_TOWNS                    55
# MELB_URBAN,SMALL_TOWNS                        32
# SMALL_CITIES,SMALL_TOWNS                       4
# RURAL_VICTORIA,MELB_URBAN                      3
# RURAL_VICTORIA,SMALL_CITIES,SMALL_TOWNS        2
# SMALL_CITIES,RURAL_VICTORIA                    2
# Name: DEG_URBAN_ALL, dtype: int64

# %%
crashes["REGION_NAME_ALL"].value_counts()
# Out:
# METROPOLITAN SOUTH EAST REGION                                   26562
# METROPOLITAN NORTH WEST REGION                                   26127
# SOUTH WESTERN REGION                                              5795
# EASTERN REGION,EASTERN REGION                                     4577
# NORTH EASTERN REGION                                              4567
# NORTHERN REGION                                                   4299
# WESTERN REGION                                                    4178
# METROPOLITAN SOUTH EAST REGION,METROPOLITAN NORTH WEST REGION      200
# EASTERN REGION,EASTERN REGION,METROPOLITAN SOUTH EAST REGION        26
# WESTERN REGION,SOUTH WESTERN REGION                                 21
# WESTERN REGION,NORTHERN REGION                                      12
# NORTH EASTERN REGION,METROPOLITAN SOUTH EAST REGION                 11
# NORTH EASTERN REGION,NORTHERN REGION                                 8
# NORTHERN REGION,METROPOLITAN NORTH WEST REGION                       6
# METROPOLITAN NORTH WEST REGION,METROPOLITAN SOUTH EAST REGION        3
# NORTH EASTERN REGION,METROPOLITAN NORTH WEST REGION                  3
# EASTERN REGION,EASTERN REGION,NORTH EASTERN REGION                   2
# NORTHERN REGION,NORTH EASTERN REGION                                 1
# WESTERN REGION,METROPOLITAN NORTH WEST REGION                        1
# Name: REGION_NAME_ALL, dtype: int64
