# %% [markdown]
# ## Hypothesis 4 testing

# %% [markdown]
# ### Do accidents increase during cold weather?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts

# %%
hume_merged = pd.read_csv('cleaned_data/merged_hume_data.csv')
hume_merged.head()
# Out:
#     ACCIDENT_NO          ABS_CODE ACCIDENT_STATUS        Date ACCIDENT_TIME  \
# 0  T20140013978  Driving accident        Finished  2014/07/07      17:45:00
# 1  T20140013706  Driving accident        Finished  2014/07/03      15:50:00
# 2  T20140014503  Driving accident        Finished  2014/07/14      13:27:00
# 3  T20140014709  Driving accident        Finished  2014/07/16      13:30:00
# 4  T20140014809  Driving accident        Finished  2014/07/17      20:40:00
#
#   ALCOHOLTIME                      ACCIDENT_TYPE DAY_OF_WEEK  \
# 0          No                  Struck Pedestrian      Monday
# 1          No             Collision with vehicle    Thursday
# 2          No             Collision with vehicle      Monday
# 3          No  No collision and no object struck   Wednesday
# 4         Yes  No collision and no object struck    Thursday
#
#                                             DCA_CODE HIT_RUN_FLAG  ...  \
# 0  PED ON FOOTHPATH STRUCK BY VEHENTERING/LEAVING...           No  ...
# 1                    REAR END(VEHICLES IN SAME LANE)           No  ...
# 2                  LANE CHANGE LEFT (NOT OVERTAKING)           No  ...
# 3        OUT OF CONTROL ON CARRIAGEWAY (ON STRAIGHT)           No  ...
# 4                            OFF CARRIAGEWAY TO LEFT           No  ...
#
#   MOTORCYCLE PUBLICVEHICLE  DEG_URBAN_NAME   DEG_URBAN_ALL LGA_NAME_ALL  \
# 0        0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# 1        1.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# 2        0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# 3        1.0           0.0  RURAL_VICTORIA  RURAL_VICTORIA         HUME
# 4        0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
#
#                   REGION_NAME_ALL             RMA  STAT_DIV_NAME  \
# 0  METROPOLITAN NORTH WEST REGION      Local Road          Metro
# 1  METROPOLITAN NORTH WEST REGION      Local Road          Metro
# 2  METROPOLITAN NORTH WEST REGION         Freeway          Metro
# 3  METROPOLITAN NORTH WEST REGION      Local Road          Metro
# 4  METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
#
#   Rainfall amount (millimetres) Maximum temperature (Degree C)
# 0                           0.2                           15.3
# 1                           0.0                           11.7
# 2                           0.4                           12.4
# 3                           0.4                           13.8
# 4                           0.0                           11.7
#
# [5 rows x 54 columns]

# %%
#Remove accidents happened due to death of the driver before the accident
hume_merged = hume_merged[hume_merged['ABS_CODE']=='Driving accident']
hume_merged.shape
# Out:
# (2294, 54)

# %% [markdown]
# ## Study accidents in both all roads and fast roads

# %% [markdown]
# ### (a) Road accident frequency in all kinds of roads against daily max temperature

# %%
# Group data by the accident date to find daily values.
grouped_df = hume_merged.groupby(["Date"])

# Assign data to axis: x_axis is max temperature (mean used but all max temperature data values are the same for the same date),
# y_axis is daily accident count  
x_a = grouped_df["Maximum temperature (Degree C)"].mean()
y_a = grouped_df["ACCIDENT_NO"].count()

# %%
# Use matplotlib to create a scatter plot
plt.scatter(x_a, y_a, marker="o", facecolors="blue", edgecolors="blue", alpha=0.5)
plt.title("Daily Temperature vs All Roads Accidents (HUME)")
plt.xlabel("Maximum Temperature (Degree C)")
plt.ylabel("All Roads Accidents Count")

#Create regression line for the data
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_a,y_a)
all_regress_values = x_a*slope+intercept
plt.plot(x_a,all_regress_values,color='r')
line_eq = 'Y='+str(round(slope,3))+'*X+'+str(round(intercept,3))
plt.annotate(line_eq,(20,6),fontsize=15,color='red')
plt.show()
print('The pvalue of this correlation is '+str(pvalue)+' ---> We cannot reject null hypothesis')
# Out:
# The pvalue of this correlation is 0.5129268234659805 ---> We cannot reject null hypothesis

# %% [markdown]
# ### (b) Fast roads accidents against daily max temperature

# %%
hume_merged['RMA'].unique()
# Out:
# array(['Local Road', 'Freeway', 'Arterial Other', 'Arterial Highway'],
#       dtype=object)

# %%
#Separate data for accidents happened on freeways only
hume_fast = hume_merged[(hume_merged['RMA']=='Arterial Highway') | (hume_merged['RMA']=='Freeway')
                         | (hume_merged['RMA']=='Arterial Other')]
hume_fast
# Out:
#        ACCIDENT_NO          ABS_CODE ACCIDENT_STATUS        Date  \
# 2     T20140014503  Driving accident        Finished  2014/07/14
# 4     T20140014809  Driving accident        Finished  2014/07/17
# 8     T20140015079  Driving accident        Finished  2014/07/22
# 10    T20140015349  Driving accident        Finished  2014/07/25
# 11    T20140015197  Driving accident        Finished  2014/07/23
# ...            ...               ...             ...         ...
# 2292  T20180022717  Driving accident        Finished  2018/11/28
# 2294  T20190001098  Driving accident        Finished  2019/01/19
# 2295  T20190006066  Driving accident        Finished  2019/03/31
# 2296  T20190009744  Driving accident        Finished  2019/05/24
# 2297  T20190012287  Driving accident        Finished  2019/06/27
#
#      ACCIDENT_TIME ALCOHOLTIME                      ACCIDENT_TYPE DAY_OF_WEEK  \
# 2         13:27:00          No             Collision with vehicle      Monday
# 4         20:40:00         Yes  No collision and no object struck    Thursday
# 8         09:15:00          No             Collision with vehicle     Tuesday
# 10        17:00:00         Yes             Collision with vehicle      Friday
# 11        17:14:00          No             Collision with vehicle   Wednesday
# ...            ...         ...                                ...         ...
# 2292      12:45:00          No             Collision with vehicle   Wednesday
# 2294      07:40:00          No      Collision with a fixed object      Friday
# 2295      13:50:00          No      Collision with a fixed object      Sunday
# 2296      09:06:00          No             Collision with vehicle      Friday
# 2297      16:05:00          No             Collision with vehicle   Wednesday
#
#                                               DCA_CODE HIT_RUN_FLAG  ...  \
# 2                    LANE CHANGE LEFT (NOT OVERTAKING)           No  ...
# 4                              OFF CARRIAGEWAY TO LEFT           No  ...
# 8      VEHICLE OFF FOOTPATH STRIKES VEH ON CARRIAGEWAY           No  ...
# 10                                       RIGHT THROUGH           No  ...
# 11                            HEAD ON (NOT OVERTAKING)           No  ...
# ...                                                ...          ...  ...
# 2292                   REAR END(VEHICLES IN SAME LANE)           No  ...
# 2294   LEFT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE           No  ...
# 2295  RIGHT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE           No  ...
# 2296                    RIGHT FAR (INTERSECTIONS ONLY)           No  ...
# 2297                   REAR END(VEHICLES IN SAME LANE)           No  ...
#
#      MOTORCYCLE PUBLICVEHICLE  DEG_URBAN_NAME   DEG_URBAN_ALL LGA_NAME_ALL  \
# 2           0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# 4           0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# 8           0.0           0.0    SMALL_CITIES    SMALL_CITIES         HUME
# 10          0.0           0.0  RURAL_VICTORIA  RURAL_VICTORIA         HUME
# 11          0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# ...         ...           ...             ...             ...          ...
# 2292        0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# 2294        0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# 2295        0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# 2296        0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
# 2297        0.0           0.0      MELB_URBAN      MELB_URBAN         HUME
#
#                      REGION_NAME_ALL             RMA  STAT_DIV_NAME  \
# 2     METROPOLITAN NORTH WEST REGION         Freeway          Metro
# 4     METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
# 8     METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
# 10    METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
# 11    METROPOLITAN NORTH WEST REGION         Freeway          Metro
# ...                              ...             ...            ...
# 2292  METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
# 2294  METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
# 2295  METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
# 2296  METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
# 2297  METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
#
#      Rainfall amount (millimetres) Maximum temperature (Degree C)
# 2                              0.4                           12.4
# 4                              0.0                           11.7
# 8                              0.0                           10.1
# 10                             0.0                           15.9
# 11                             0.0                           12.4
# ...                            ...                            ...
# 2292                           0.0                           20.9
# 2294                           2.4                           24.0
# 2295                           1.8                           20.0
# 2296                           0.0                           18.8
# 2297                           0.0                           16.1
#
# [1343 rows x 54 columns]

# %%
# Group data by the accident date to find daily values.
grouped_fast = hume_fast.groupby(["Date"])

# Assign data to axis: x_axis is max temperature (mean used but all max temperature data values are the same for the same date),
# y_axis is daily accident count  
x_f = grouped_fast["Maximum temperature (Degree C)"].mean()
y_f = grouped_fast["ACCIDENT_NO"].count()

# %%
# Use matplotlib to create a scatter plot
plt.scatter(x_f, y_f, marker="o", facecolors="blue", edgecolors="blue", alpha=0.5)
plt.title("Daily Temperature vs Fast Roads Accidents (HUME)")
plt.xlabel("Maximum Temperature (Degree C)")
plt.ylabel("Fast Road Accidents")

#Create regression line for the data
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_f,y_f)
fast_regress_values = x_f*slope+intercept
plt.plot(x_f,fast_regress_values,color='r')
line_eq = 'Y='+str(round(slope,3))+'*X+'+str(round(intercept,3))
plt.annotate(line_eq,(20,5),fontsize=15,color='red')
plt.show()
print('The pvalue of this correlation is '+str(pvalue)+' ---> We cannot reject null hypothesis')
# Out:
# The pvalue of this correlation is 0.5065872362890801 ---> We cannot reject null hypothesis
