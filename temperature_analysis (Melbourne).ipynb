# %% [markdown]
# ## Hypothesis 4 testing

# %% [markdown]
# ### Do accidents increase during cold weather?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts

# %%
melb_merged = pd.read_csv('cleaned_data/merged_melb_data.csv')
melb_merged.head()
# Out:
#     ACCIDENT_NO          ABS_CODE ACCIDENT_STATUS        Date ACCIDENT_TIME  \
# 0  T20140013533  Driving accident      Unfinished  2014/07/01      18:05:00
# 1  T20140013680  Driving accident        Finished  2014/07/03      11:00:00
# 2  T20140013898  Driving accident        Finished  2014/07/03      10:30:00
# 3  T20140013771  Driving accident        Finished  2014/07/04      17:40:00
# 4  T20140013792  Driving accident        Finished  2014/07/04      23:13:00
#
#   ALCOHOLTIME                      ACCIDENT_TYPE DAY_OF_WEEK  \
# 0         Yes             Collision with vehicle      Monday
# 1          No  No collision and no object struck    Thursday
# 2          No     Fall from or in moving vehicle    Thursday
# 3          No  No collision and no object struck    Thursday
# 4         Yes             Collision with vehicle    Thursday
#
#                                       DCA_CODE HIT_RUN_FLAG  ... MOTORCYCLE  \
# 0              REAR END(VEHICLES IN SAME LANE)           No  ...        0.0
# 1                     OFF CARRIAGEWAY TO RIGHT           No  ...        1.0
# 2                         FELL IN/FROM VEHICLE           No  ...        0.0
# 3  OUT OF CONTROL ON CARRIAGEWAY (ON STRAIGHT)           No  ...        1.0
# 4                                RIGHT THROUGH           No  ...        1.0
#
#   PUBLICVEHICLE DEG_URBAN_NAME  DEG_URBAN_ALL LGA_NAME_ALL  \
# 0           0.0     MELB_URBAN     MELB_URBAN    MELBOURNE
# 1           0.0  MELBOURNE_CBD  MELBOURNE_CBD    MELBOURNE
# 2           1.0     MELB_URBAN     MELB_URBAN    MELBOURNE
# 3           0.0     MELB_URBAN     MELB_URBAN    MELBOURNE
# 4           0.0  MELBOURNE_CBD  MELBOURNE_CBD    MELBOURNE
#
#                   REGION_NAME_ALL             RMA  STAT_DIV_NAME  \
# 0  METROPOLITAN NORTH WEST REGION         Freeway          Metro
# 1  METROPOLITAN NORTH WEST REGION      Local Road          Metro
# 2  METROPOLITAN NORTH WEST REGION      Local Road          Metro
# 3  METROPOLITAN NORTH WEST REGION      Local Road          Metro
# 4  METROPOLITAN NORTH WEST REGION  Arterial Other          Metro
#
#   Rainfall amount (millimetres) Maximum temperature (Degree C)
# 0                           0.4                           13.3
# 1                           0.0                           13.1
# 2                           0.0                           13.1
# 3                           0.0                           12.8
# 4                           0.0                           12.8
#
# [5 rows x 54 columns]

# %%
#Remove accidents happened due to death of the driver before the accident
melb_merged = melb_merged[melb_merged['ABS_CODE']=='Driving accident']
melb_merged.shape
# Out:
# (3887, 54)

# %% [markdown]
# ## Study accidents in both all roads and fast roads

# %% [markdown]
# ### (a) Road accident frequency in all kinds of roads against daily max temperature

# %%
# Group data by the accident date to find daily values.
grouped_df = melb_merged.groupby(["Date"])

# Assign data to axis: x_axis is max temperature (mean used but all max temperature data values are the same for the same date),
# y_axis is daily accident count  
x_a = grouped_df["Maximum temperature (Degree C)"].mean()
y_a = grouped_df["ACCIDENT_NO"].count()

# %%
# Use matplotlib to create a scatter plot
plt.scatter(x_a, y_a, marker="o", facecolors="blue", edgecolors="blue", alpha=0.5)
plt.title("Daily Temperature vs All Roads Accidents (Melbourne)")
plt.xlabel("Maximum Temperature (Degree C)")
plt.ylabel("All Roads Accidents Count")

#Create regression line for the data
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_a,y_a)
all_regress_values = x_a*slope+intercept
plt.plot(x_a,all_regress_values,color='r')
line_eq = 'Y='+str(round(slope,2))+'*X+'+str(round(intercept,2))
plt.annotate(line_eq,(25,10),fontsize=15,color='red')
plt.show()
print('The pvalue of this correlation is '+str(pvalue)+' ---> We cannot reject null hypothesis')
# Out:
# The pvalue of this correlation is 0.06065109213569775 ---> We cannot reject null hypothesis

# %% [markdown]
# ### (b) Fast roads accidents against daily max temperature

# %%
melb_merged['RMA'].unique()
# Out:
# array(['Freeway', 'Local Road', 'Arterial Other', 'Arterial Highway'],
#       dtype=object)

# %%
#Separate data for accidents happened on freeways only
melb_fast = melb_merged[(melb_merged['RMA']=='Arterial Highway') | (melb_merged['RMA']=='Freeway')
                         | (melb_merged['RMA']=='Arterial Other')]
melb_fast
# Out:
#        ACCIDENT_NO          ABS_CODE ACCIDENT_STATUS        Date  \
# 0     T20140013533  Driving accident      Unfinished  2014/07/01
# 4     T20140013792  Driving accident        Finished  2014/07/04
# 6     T20140013781  Driving accident        Finished  2014/07/04
# 9     T20140013895  Driving accident        Finished  2014/07/06
# 12    T20140014421  Driving accident        Finished  2014/07/12
# ...            ...               ...             ...         ...
# 3875  T20180011149  Driving accident        Finished  2018/06/12
# 3876  T20180012710  Driving accident        Finished  2018/07/06
# 3877  T20180015801  Driving accident        Finished  2018/08/21
# 3881  T20180018480  Driving accident        Finished  2018/10/01
# 3886  T20190008585  Driving accident        Finished  2019/05/07
#
#      ACCIDENT_TIME ALCOHOLTIME           ACCIDENT_TYPE DAY_OF_WEEK  \
# 0         18:05:00         Yes  Collision with vehicle      Monday
# 4         23:13:00         Yes  Collision with vehicle    Thursday
# 6         18:45:00         Yes  Collision with vehicle      Friday
# 9         11:38:00          No  Collision with vehicle      Sunday
# 12        12:59:00          No  Collision with vehicle    Saturday
# ...            ...         ...                     ...         ...
# 3875      09:30:00          No  Collision with vehicle      Monday
# 3876      21:25:00         Yes  Collision with vehicle      Friday
# 3877      08:05:00          No  Collision with vehicle     Tuesday
# 3881      20:45:00         Yes  Collision with vehicle      Monday
# 3886      07:37:00          No  Collision with vehicle     Tuesday
#
#                                           DCA_CODE HIT_RUN_FLAG  ...  \
# 0                  REAR END(VEHICLES IN SAME LANE)           No  ...
# 4                                    RIGHT THROUGH           No  ...
# 6                  REAR END(VEHICLES IN SAME LANE)           No  ...
# 9                  REAR END(VEHICLES IN SAME LANE)           No  ...
# 12                 REAR END(VEHICLES IN SAME LANE)           No  ...
# ...                                            ...          ...  ...
# 3875                          RIGHT TURN SIDESWIPE           No  ...
# 3876                                 RIGHT THROUGH          Yes  ...
# 3877               REAR END(VEHICLES IN SAME LANE)           No  ...
# 3881                                 RIGHT THROUGH    Not known  ...
# 3886  LANE SIDE SWIPE (VEHICLES IN PARALLEL LANES)           No  ...
#
#      MOTORCYCLE PUBLICVEHICLE DEG_URBAN_NAME             DEG_URBAN_ALL  \
# 0           0.0           0.0     MELB_URBAN                MELB_URBAN
# 4           1.0           0.0  MELBOURNE_CBD             MELBOURNE_CBD
# 6           0.0           0.0     MELB_URBAN                MELB_URBAN
# 9           0.0           0.0     MELB_URBAN                MELB_URBAN
# 12          0.0           0.0     MELB_URBAN                MELB_URBAN
# ...         ...           ...            ...                       ...
# 3875        0.0           1.0     MELB_URBAN                MELB_URBAN
# 3876        0.0           0.0     MELB_URBAN                MELB_URBAN
# 3877        0.0           0.0  MELBOURNE_CBD  MELB_URBAN,MELBOURNE_CBD
# 3881        1.0           0.0     MELB_URBAN                MELB_URBAN
# 3886        0.0           0.0     MELB_URBAN                MELB_URBAN
#
#          LGA_NAME_ALL                 REGION_NAME_ALL               RMA  \
# 0           MELBOURNE  METROPOLITAN NORTH WEST REGION           Freeway
# 4           MELBOURNE  METROPOLITAN NORTH WEST REGION    Arterial Other
# 6           MELBOURNE  METROPOLITAN NORTH WEST REGION           Freeway
# 9           MELBOURNE  METROPOLITAN NORTH WEST REGION           Freeway
# 12          MELBOURNE  METROPOLITAN NORTH WEST REGION           Freeway
# ...               ...                             ...               ...
# 3875  MELBOURNE,YARRA  METROPOLITAN NORTH WEST REGION    Arterial Other
# 3876        MELBOURNE  METROPOLITAN NORTH WEST REGION           Freeway
# 3877        MELBOURNE  METROPOLITAN NORTH WEST REGION  Arterial Highway
# 3881        MELBOURNE  METROPOLITAN NORTH WEST REGION  Arterial Highway
# 3886        MELBOURNE  METROPOLITAN NORTH WEST REGION           Freeway
#
#       STAT_DIV_NAME Rainfall amount (millimetres)  \
# 0             Metro                           0.4
# 4             Metro                           0.0
# 6             Metro                           0.0
# 9             Metro                           0.2
# 12            Metro                           4.4
# ...             ...                           ...
# 3875          Metro                           0.4
# 3876          Metro                           0.0
# 3877          Metro                           1.2
# 3881          Metro                           0.0
# 3886          Metro                           0.0
#
#      Maximum temperature (Degree C)
# 0                              13.3
# 4                              12.8
# 6                              12.8
# 9                              13.8
# 12                             10.4
# ...                             ...
# 3875                           16.6
# 3876                           15.2
# 3877                           12.4
# 3881                           23.3
# 3886                           18.7
#
# [2193 rows x 54 columns]

# %%
# Group data by the accident date to find daily values.
grouped_fast = melb_fast.groupby(["Date"])

# Assign data to axis: x_axis is max temperature (mean used but all max temperature data values are the same for the same date),
# y_axis is daily accident count  
x_f = grouped_fast["Maximum temperature (Degree C)"].mean()
y_f = grouped_fast["ACCIDENT_NO"].count()

# %%
# Use matplotlib to create a scatter plot
plt.scatter(x_f, y_f, marker="o", facecolors="blue", edgecolors="blue", alpha=0.5)
plt.title("Daily Temperature vs Fast Roads Accidents (Melbourne)")
plt.xlabel("Maximum Temperature (Degree C)")
plt.ylabel("Fast Road Accidents")

#Create regression line for the data
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x_f,y_f)
fast_regress_values = x_f*slope+intercept
plt.plot(x_f,fast_regress_values,color='r')
line_eq = 'Y='+str(round(slope,2))+'*X+'+str(round(intercept,2))
plt.annotate(line_eq,(15,6.5),fontsize=15,color='red')
plt.show()
print('The pvalue of this correlation is '+str(pvalue)+' ---> We cannot reject null hypothesis')
# Out:
# The pvalue of this correlation is 0.1249646196815673 ---> We cannot reject null hypothesis
